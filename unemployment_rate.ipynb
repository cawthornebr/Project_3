# %%
from flask import Flask, jsonify, redirect, render_template
from scipy import stats
import numpy as np
import pandas as pd
import datetime as dt
from datetime import datetime
from dateutil.relativedelta import relativedelta
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, inspect, func
import pprint

# %%
import requests
import json
import prettytable
headers = {'Content-type': 'application/json'}
data = json.dumps({"seriesid": ['LAUST010000000000003','LAUST020000000000003']
,"startyear":"2018", "endyear":"2020"})
p = requests.post('https://api.bls.gov/publicAPI/v2/timeseries/data/', data=data, headers=headers)
json_data = json.loads(p.text)
for series in json_data['Results']['series']:
    x=prettytable.PrettyTable(["series id","year","period","value"])
    seriesId = series['seriesID']
    for item in series['data']:
        year = item['year']
        period = item['period']
        value = item['value']
        #footnotes=""
        #for footnote in item['footnotes']:
           # if footnote:
                #footnotes = footnotes + footnote['text'] + ','

# %%
#print(p)
#print(data)
#pprint.pprint(json_data)
#print(series)
#print(seriesId)
#print.pprint(value)

# %%
#for element in json_data:
   # for value in json_data['Results'].items():
      #  pprint.pprint(value)
        #pprint.pprint(series['data'][0]['periodName'])
        #pprint.pprint(series['data'][0]['periodName'])
       # pprint.pprint(series['data'][0]['year'])
        #pprint.pprint(series['data'][0]['value'])
        #print(period)
        #print(periodName)
        #print(value)
       #print(year)

# %%
for value in json_data['Results']:
    for i in series['data']:
        pprint.pprint(series['data'][0]['year'])
        pprint.pprint(series['data'][0]['periodName'])
        pprint.pprint(series['data'][0]['value'])
# Out:
# '2020'
# 'March'
# '5.8'
# '2020'
# 'March'
# '5.8'
# '2020'
# 'March'
# '5.8'
# '2020'
# 'March'
# '5.8'
# '2020'
# 'March'
# '5.8'
# '2020'
# 'March'
# '5.8'
# '2020'
# 'March'
# '5.8'
# '2020'
# 'March'
# '5.8'
# '2020'
# 'March'
# '5.8'
# '2020'
# 'March'
# '5.8'
# '2020'
# 'March'
# '5.8'
# '2020'
# 'March'
# '5.8'
# '2020'
# 'March'
# '5.8'
# '2020'
# 'March'
# '5.8'
# '2020'
# 'March'
# '5.8'
# '2020'
# 'March'
# '5.8'
# '2020'
# 'March'
# '5.8'
# '2020'
# 'March'
# '5.8'
# '2020'
# 'March'
# '5.8'
# '2020'
# 'March'
# '5.8'
# '2020'
# 'March'
# '5.8'
# '2020'
# 'March'
# '5.8'
# '2020'
# 'March'
# '5.8'
# '2020'
# 'March'
# '5.8'
# '2020'
# 'March'
# '5.8'
# '2020'
# 'March'
# '5.8'
# '2020'
# 'March'
# '5.8'

# %%
#for item in value:
    #pprint.pprint(value['data'])
   # pprint.pprint(item)
    ##pprint.pprint(data)
    #pprint.pprint(value['seriesID'])
    #pprint.pprint(value['data']['period'])
# Out:
# 'seriesID'
# 'data'

# %%
year_list = []
month_list = []
unemployment_rate_list = []
state_list = []

for state in series:
    for value in series['data']:
        #pprint.pprint(value)
        month = (value['periodName'])
        #pprint.pprint(month)
        year = (value['year'])
        #pprint.pprint(year)
        unemployment_rate = (value['value'])
        #pprint.pprint(unemployment_rate)
        seriesID = series['seriesID']
        #pprint.pprint(seriesID)

        year_list.append(year)
        month_list.append(month)
        unemployment_rate_list.append(unemployment_rate)
        state_list.append(seriesID)

#print(year_list)
print(len(year_list))
#print(month_list)
#print(unemployment_rate_list)
print(len(state_list))
print(state_list)
# Out:
# 54
# 54
# ...

# %%
updated_state_list = []

for string in state_list:
    new_state = string.replace('LAUST010000000000003', 'Alabama')
    updated_state_list.append(new_state)
    
#print(updated_state_list)

# %%
unemployment_df = pd.DataFrame(list(zip(updated_state_list, month_list,year_list, unemployment_rate_list)),columns=['State', 'Month', 'Year','Unemployment Rate'])
unemployment_df
# Out:
#                    State      Month  Year Unemployment Rate
# 0   LAUST020000000000003      March  2020               5.8
# 1   LAUST020000000000003   February  2020               5.9
# 2   LAUST020000000000003    January  2020               6.6
# 3   LAUST020000000000003   December  2019               6.1
# 4   LAUST020000000000003   November  2019               6.1
# 5   LAUST020000000000003    October  2019               5.7
# 6   LAUST020000000000003  September  2019               5.5
# 7   LAUST020000000000003     August  2019               5.3
# 8   LAUST020000000000003       July  2019               5.6
# 9   LAUST020000000000003       June  2019               6.3
# 10  LAUST020000000000003        May  2019               6.0
# 11  LAUST020000000000003      April  2019               6.3
# 12  LAUST020000000000003      March  2019               6.8
# 13  LAUST020000000000003   February  2019               7.0
# 14  LAUST020000000000003    January  2019               6.9
# ...
